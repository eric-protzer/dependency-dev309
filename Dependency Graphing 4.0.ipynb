# %% [markdown]
# ## edit the box below to choose your countries and years

# %%
mycountry = ['THA']
peers = ['CHN', 'LAO', 'THA', 'AGO', 'MMR', 'UZB', 'WSM']
years = [1995, 2000, 2005, 2010, 2015]

# %% [markdown]
# ## don't edit below here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
mycountries = peers + mycountry
data = pd.read_csv('data_out.csv')
data = data[data.year.isin(years)]

# %% [markdown]
# ## graphs are down here

# %%
#electricity

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['elec_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['elec_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['elec_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['elec_mean'], yerr=data.loc[data.ISO == mycountry[0]]['elec_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by Electricity Dependence')
plt.show()

# %%
#rail

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['rail_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['rail_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['rail_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['rail_mean'], yerr=data.loc[data.ISO == mycountry[0]]['rail_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by Rail Transport Dependence')
plt.show()

# %%
#truck

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['truck_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['truck_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['truck_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['truck_mean'], yerr=data.loc[data.ISO == mycountry[0]]['truck_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by Truck Transport Dependence')
plt.show()

# %%
#internet

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['internet_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['internet_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['internet_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['internet_mean'], yerr=data.loc[data.ISO == mycountry[0]]['internet_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by Internet Dependence')
plt.show()

# %%
#water

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['water_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['water_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['water_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['water_mean'], yerr=data.loc[data.ISO == mycountry[0]]['water_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by water Dependence')
plt.show()

# %%
#human capital

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['hc_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['hc_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['hc_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['hc_mean'], yerr=data.loc[data.ISO == mycountry[0]]['hc_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by Human Capital Dependence')
plt.show()

# %%
#capital

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['capital_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['capital_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['capital_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['capital_mean'], yerr=data.loc[data.ISO == mycountry[0]]['capital_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by Capital Dependence')
plt.show()

# %%
#land

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['land_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['land_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['land_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['land_mean'], yerr=data.loc[data.ISO == mycountry[0]]['land_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by Land Dependence')
plt.show()

# %%
#contract

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['contract_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['contract_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['contract_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['contract_mean'], yerr=data.loc[data.ISO == mycountry[0]]['contract_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by Contract Dependence')
plt.show()

# %%
#external finance

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(data.loc[~data.ISO.isin(mycountries)]['year'], data.loc[~data.ISO.isin(mycountries)]['ed_mean'], c="gray")
ax.scatter(data.loc[data.ISO.isin(peers)]['year'], data.loc[data.ISO.isin(peers)]['ed_mean'], c="blue")
ax.scatter(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['ed_mean'], c="red")
(_, caps, _) = ax.errorbar(data.loc[data.ISO == mycountry[0]]['year'], data.loc[data.ISO == mycountry[0]]['ed_mean'], yerr=data.loc[data.ISO == mycountry[0]]['ed_error'], fmt='o', capsize=5, c="red")
for cap in caps:
    cap.set_markeredgewidth(1)
ax.legend(['Rest of World', 'Peers', mycountry[0]], loc=9, bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Dependency Coefficient', fontsize=12)
plt.title('Concentration of Exports by External Finance Dependence')
plt.show()
